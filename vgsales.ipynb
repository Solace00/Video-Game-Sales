# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
pd.plotting.register_matplotlib_converters()
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data = pd.read_csv("./vgsales.csv")

# %%
data
# Out:
#         Rank                                              Name Platform
# 0          1                                        Wii Sports      Wii  \
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %%
data.shape
# Out:
# (16598, 11)

# %%
data.isnull().sum() #checking for total null values
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# **Their fields and data types are:**
#
# - Rank - Ranking of overall sales, integer
# - Name - The games name
# - Platform - Platform of the games release (i.e. PC,PS4, etc.), object
# - Year - Year of the game's release, float
# - Genre - Genre of the game ,object
# - Publisher - Publisher of the game, object
# - NA_Sales - Sales in North America (in millions), float
# - EU_Sales - Sales in Europe (in millions), float
# - JP_Sales - Sales in Japan (in millions), float
# - Other_Sales - Sales in the rest of the world (in millions), float
# - Global_Sales - Total worldwide sales, float

# %%
print(data.describe)
data.describe()
# Out:
# <bound method NDFrame.describe of         Rank                                              Name Platform
# 0          1                                        Wii Sports      Wii  \
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales
# ...

# %%
data['Genre'].value_counts()
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %% [markdown]
# ## Columns

# %%
data['Genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
data["Platform"].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
data['Year'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000.,   nan, 1995., 2016., 1991., 1981., 1987.,
#        1980., 1983., 2020., 2017.])

# %%
data[data['Year'].isin([2017,2018,2019,2020])]
# Out:
#         Rank                                              Name Platform
# 5957    5959                            Imagine: Makeup Artist       DS  \
# 14390  14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16241  16244  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 16438  16441                  Brothers Conflict: Precious Baby      PSV
#
#          Year         Genre     Publisher  NA_Sales  EU_Sales  JP_Sales
# 5957   2020.0    Simulation       Ubisoft      0.27       0.0      0.00  \
# 14390  2017.0  Role-Playing          Sega      0.00       0.0      0.03
# 16241  2017.0  Role-Playing          Sega      0.00       0.0      0.01
# 16438  2017.0        Action  Idea Factory      0.00       0.0      0.01
#
#        Other_Sales  Global_Sales
# 5957          0.02          0.29
# 14390         0.00          0.03
# 16241         0.00          0.01
# 16438         0.00          0.01

# %%
data.drop(data[data['Year'].isin([2017,2018,2019,2020])].index,inplace=True)
## NOt enough data

# %% [markdown]
# ## Most sold games

# %%
data.sort_values(by='Global_Sales',ascending=False).head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo  \
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
sns.barplot(y=data.Name.head(10),x=data.Global_Sales.head(10));
plt.title("Top Selling Games");

# %% [markdown]
# #### Trend of Video_game_sales over the years

# %%
sales_per_year = data.groupby('Year')['Global_Sales'].sum()

# %%
sales_per_year
# Out:
# Year
# 1980.0     11.38
# 1981.0     35.77
# 1982.0     28.86
# 1983.0     16.79
# 1984.0     50.36
# 1985.0     53.94
# 1986.0     37.07
# 1987.0     21.74
# 1988.0     47.22
# 1989.0     73.45
# 1990.0     49.39
# 1991.0     32.23
# 1992.0     76.16
# 1993.0     45.98
# 1994.0     79.17
# 1995.0     88.11
# 1996.0    199.15
# 1997.0    200.98
# 1998.0    256.47
# 1999.0    251.27
# 2000.0    201.56
# 2001.0    331.47
# 2002.0    395.52
# 2003.0    357.85
# 2004.0    419.31
# 2005.0    459.94
# 2006.0    521.04
# 2007.0    611.13
# 2008.0    678.90
# 2009.0    667.30
# 2010.0    600.45
# 2011.0    515.99
# 2012.0    363.54
# 2013.0    368.11
# 2014.0    337.05
# 2015.0    264.44
# 2016.0     70.93
# Name: Global_Sales, dtype: float64

# %%
sns.lineplot(y=sales_per_year,x=sales_per_year.index)
plt.title("Sales over the years")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ## Genre with highest sales

# %%
genre_sales = data.groupby(["Genre"])["Global_Sales"].sum().sort_values(ascending=False)

# %%
genre_sales
# Out:
# Genre
# Action          1751.17
# Sports          1330.93
# Shooter         1037.37
# Role-Playing     927.33
# Platform         831.37
# Misc             809.96
# Racing           732.04
# Fighting         448.91
# Simulation       391.91
# Puzzle           244.95
# Adventure        239.04
# Strategy         175.12
# Name: Global_Sales, dtype: float64

# %%
data_loc=genre_sales
labels=[]
for x in genre_sales.index:
    labels.append(x)

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=genre_sales.index,y=genre_sales)
plt.ylabel("Sales")
plt.title("Genre Sales")
plt.xticks(rotation=45);

# %%
#colors = sns.color_palette('pastel')[0:12]
plt.pie(data_loc,labels=labels, autopct='%.0f%%')
plt.figure(figsize=(12,7))
plt.show();

# %% [markdown]
# ## Platform with highest sales

# %%
plt.figure(figsize=(16,9))
plt.title('WHAT PLATFORM DO THE GAMES GET PLAYED THE MOST')
sns.countplot(data=data, x = 'Platform', order = data['Platform'].value_counts().index)
# Out:
# <Axes: title={'center': 'WHAT PLATFORM DO THE GAMES GET PLAYED THE MOST'}, xlabel='Platform', ylabel='count'>

# %% [markdown]
# ## Game of the year 1980-2016

# %%
Top_Games_perY=data[data.groupby("Year")["Global_Sales"].transform(max)==data['Global_Sales']]
Top_Games_perY=Top_Games_perY.set_index('Year').sort_values(by="Year")
Top_Games_perY
# Out:
#         Rank                                       Name Platform
# Year
# 1980.0   259                                  Asteroids     2600  \
# 1981.0   240                                   Pitfall!     2600
# 1982.0    90                                    Pac-Man     2600
# 1983.0   422                                   Baseball      NES
# 1984.0    10                                  Duck Hunt      NES
# 1985.0     2                          Super Mario Bros.      NES
# 1986.0   128                        The Legend of Zelda      NES
# 1987.0   252            Zelda II: The Adventure of Link      NES
# 1988.0    23                        Super Mario Bros. 3      NES
# 1989.0     6                                     Tetris       GB
# 1990.0    19                          Super Mario World     SNES
# 1991.0   232    The Legend of Zelda: A Link to the Past     SNES
# 1992.0    51         Super Mario Land 2: 6 Golden Coins       GB
# ...

# %%
data.groupby(['Genre','Platform'])["Global_Sales"].mean().sort_values(ascending=False).head(10)
# Out:
# Genre         Platform
# Shooter       NES         5.088571
# Adventure     NES         4.380000
# Role-Playing  GB          4.201905
# Adventure     GB          3.432000
# Platform      NES         3.420714
# Puzzle        GB          3.164667
# Platform      GB          2.890000
# Racing        WiiU        2.590000
# Platform      SNES        2.525000
# Racing        NES         2.445000
# Name: Global_Sales, dtype: float64

# %% [markdown]
# ## Trend of video games Sales between regions
#
# #### Sales between different regions

# %%
# Melt the DataFrame
games_melted = pd.melt(data, 
                       id_vars=['Name',"Year"], 
                       value_vars=['NA_Sales','EU_Sales', 'JP_Sales', 'Other_Sales'], 
                       var_name='Region', 
                       value_name='Sales')

# Now we can graph our boxplot
sns.boxplot(x='Region', y='Sales', data=games_melted, palette='rocket', showfliers=False)
sns.despine()

# %%
over_year = data.groupby(['Year'])[['NA_Sales','JP_Sales','EU_Sales','Other_Sales']].sum()

# %%
over_year.plot()
plt.title("Trend of sales over Regions")
plt.ylabel("Sales");

# %%
#sns.histplot(data=df,x="Year",bins=36)
#plt.figure(figsize=(16,9))
fig=px.histogram(data,
                 x='Year',
                 marginal='box',
                 color_discrete_sequence=['Green'],
                 title="Games count")
fig.update_layout(bargap=0.1)
fig.show()

# %% [markdown]
# #### Years in which most games were released.

# %%
data['Year'].value_counts().head()
# Out:
# Year
# 2009.0    1431
# 2008.0    1428
# 2010.0    1259
# 2007.0    1202
# 2011.0    1139
# Name: count, dtype: int64

# %% [markdown]
# #### Years with least number of game releases.

# %%
data['Year'].value_counts().tail()
# Out:
# Year
# 1987.0    16
# 1988.0    15
# 1984.0    14
# 1985.0    14
# 1980.0     9
# Name: count, dtype: int64
